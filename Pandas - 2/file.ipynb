# %%
import pandas as pd

# %%
df = pd.read_csv('so-df/survey_results_public.csv')
# df
# df.head()
df.tail()
# Out:
#        ResponseId                      MainBranch              Age  \
# 65432       65433  I am a developer by profession  18-24 years old
# 65433       65434  I am a developer by profession  25-34 years old
# 65434       65435  I am a developer by profession  25-34 years old
# 65435       65436  I am a developer by profession  18-24 years old
# 65436       65437     I code primarily as a hobby  18-24 years old
#
#                 Employment                            RemoteWork   Check  \
# 65432  Employed, full-time                                Remote  Apples
# 65433  Employed, full-time                                Remote  Apples
# 65434  Employed, full-time                             In-person  Apples
# 65435  Employed, full-time  Hybrid (some remote, some in-person)  Apples
# 65436   Student, full-time                                   NaN  Apples
#
#                                         CodingActivities  \
# 65432                      Hobby;School or academic work
# ...

# %%
df.shape # attribute
# Out:
# (65437, 114)

# %%
df.info() # method
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65437 entries, 0 to 65436
# Columns: 114 entries, ResponseId to JobSat
# dtypes: float64(13), int64(1), object(100)
# memory usage: 56.9+ MB

# %%
pd.set_option('display.max_columns', 114)

# %%
people = {
    "first": ["Anurag", "John"],
    "last": ["Verma", "Doe"],
    "email": ["test@gmail.com", "Johndoe@gmail.com"]
}

# people = [
#     {
#         "name": "Anurag",
#         "email": "test@gmail.com",
#         "city": "Jaipur"
#     },
#     {
#         "name": "Harmeet",
#         "email": "test@gmail.com",
#         "city": "Punjab"
#     },
# ]

# %%
people["email"]
# Out:
# ['test@gmail.com', 'Johndoe@gmail.com']

# %%
df = pd.DataFrame(people)
df
# Out:
#     first   last              email
# 0  Anurag  Verma     test@gmail.com
# 1    John    Doe  Johndoe@gmail.com

# %%
df.email
# Out:
# 0       test@gmail.com
# 1    Johndoe@gmail.com
# Name: email, dtype: object

# %%
df.columns
# Out:
# Index(['ResponseId', 'MainBranch', 'Age', 'Employment', 'RemoteWork', 'Check',
#        'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        ...
#        'JobSatPoints_6', 'JobSatPoints_7', 'JobSatPoints_8', 'JobSatPoints_9',
#        'JobSatPoints_10', 'JobSatPoints_11', 'SurveyLength', 'SurveyEase',
#        'ConvertedCompYearly', 'JobSat'],
#       dtype='object', length=114)

# %%
# df.iloc[0]  # loc
df.iloc[[0, 1], 2]  # df.iloc[[row], column]
# Out:
#     first   last              email
# 0  Anurag  Verma     test@gmail.com
# 1    John    Doe  Johndoe@gmail.com

# %%
df.loc[[0,1], ['email', 'first']]  # df.loc[[row], 'column']
# Out:
#                email   first
# 0     test@gmail.com  Anurag
# 1  Johndoe@gmail.com    John

# %%
df.loc[0:1, 'email']  # df.loc[row_start:row_end, col_start:col_end]
df.loc[0:1, 'first':'email']
# Out:
#     first   last              email
# 0  Anurag  Verma     test@gmail.com
# 1    John    Doe  Johndoe@gmail.com

# %%
df.set_index('email') # inplace=False by default
# Out:
#                     first   last
# email
# test@gmail.com     Anurag  Verma
# Johndoe@gmail.com    John    Doe

# %%
df.index
# Out:
# RangeIndex(start=0, stop=65437, step=1)

# %%
df.reset_index(inplace=True)

# %%
# fil = (df['last'] == 'Doe') & (df['first'] == 'John')
fil = (df['last'] == 'Doe') | (df['first'] == 'Anurag')

# %%
df[fil]
# Out:
#    index   first   last              email
# 0      0  Anurag  Verma     test@gmail.com
# 1      1    John    Doe  Johndoe@gmail.com

# %%
# df.loc[fil, 'email']
df.loc[~fil, 'email']
# Out:
# Series([], Name: email, dtype: object)

# %%
high_response = (df['ResponseId'] > 60000)
high_response
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 65432     True
# 65433     True
# 65434     True
# 65435     True
# 65436     True
# Name: ResponseId, Length: 65437, dtype: bool

# %%
df.loc[high_response, ['Country']]
# Out:
#                         Country
# 60000                       NaN
# 60001  United States of America
# 60002                       NaN
# 60003                       NaN
# 60004  United States of America
# ...                         ...
# 65432                       NaN
# 65433                       NaN
# 65434                       NaN
# 65435                   Germany
# 65436                       NaN
#
# [5437 rows x 1 columns]

# %%
countries = ['India', 'United States', 'Canada', 'Germany']

filt = df['Country'].isin(countries)
df.loc[filt, 'Country']

# filt = df['LanguageWorkedWith'].str.contains('Python', na=False)
# df.loc[filt, 'LanguageWorkedWith']
# Out:
# 3         Canada
# 16        Canada
# 17         India
# 18       Germany
# 20       Germany
#           ...
# 65383      India
# 65413      India
# 65415      India
# 65428      India
# 65435    Germany
# Name: Country, Length: 11282, dtype: object
